# %% [markdown]
# # **Data Analysis Assignment**
#
# ## **Objective**
# In this assignment, you will work with a student dataset to apply and reinforce your knowledge of **pandas, numpy, matplotlib**, and linear regression with **scikit-learn**.
#
# Download and import in a dataframe the CSV file containing the data from this link:
#
# https://raw.githubusercontent.com/pal-dev-labs/Become-a-Data-Scientist-with-Python-and-AI/refs/heads/main/Data/student_performance_dataset.csv
#
# ---
#
# ## **1. Loading the Dataset**
#
# Write code to:
# - Load the CSV file into a pandas DataFrame
# - Display the first 5 rows of the DataFrame
#
# ---
#
# ## **2. Data Cleaning**
#
# Write code to:
# - Check for missing values (NaN) in the dataset
# - Replace any missing values with the column mean
# - Verify that no NaN values remain
#
# ---
#
# ## **3. Pandas Exercises**
#
# ### **Exercise 1**
# Extract all rows for students who use their smartphone for more than 5 hours a day.
#
# ### Exercise 2: Data Filtering & Aggregation
# Objective: Filter data and compute group-wise statistics.
#
# Tasks:
# - Filter students who study more than 6 hours and have a math average ≥ 7.
#
# - Compute the average math grade per class.
#
# - Find the class with the highest average smartphone usage.
#
# - Group by student_class and compute mean study hours and mean sleep hours.
#
# ---
#
# ## **4. Data Plotting**
#
# Create a scatter plot to visualize the relationship between **hours_of_sleep** and **math_average**.
# Create a scatter plot to visualize the relationship between **hours_of_smartphone** and **math_average**.
# Create a scatter plot to visualize the relationship between **hours_of_study** and **math_average**.
# hours_of_study	hours_of_smartphone	hours_of_sleep
#
# ---
#
# ## **5. Numpy Exercises**
#
# ### **Exercise 1**
# Extract **hours_of_study,hours_of_smartphone,hours_of_sleep **
#  columns as numpy arrays.
#
# ### **Exercise 2**
# Find the student with the maximum **hours_of_study,hours_of_smartphone,hours_of_sleep ** value.
#
# ---
#
# ## **6. Using Loops and Conditional Statements**
#
# ### **Exercise 1: `for` Loop**
# Using for cycle Print the number of students with an average grade above 8.
#
# ### **Exercise 3: `if-elif-else` Structure**
# Classify students based on their average grade:
# - `>= 9` → "Excellent"
# - `>= 7` and `< 9` → "Good"
# - `= 6` → "Enough"
# - < 6 → "need improvements"
#
# ---
#
# ## **7. Using Dictionaries**
#
# Create a Python dictionary that maps each student to their average grade.
#
# Print the average grade of the student with ID 10.
#
# ---
#
# ## **8. Linear Regression**
#
# ### **Exercise 1: Single Variable Regression**
# Use the `sklearn` library to create a linear regression model between
# **hours_of_study** and **math_average**
#
# ### **Exercise 2: Multiple Variable Regression**
# Create a model that uses all predictors to compute math-average
#
#
# ### **End of the Assignment!** 🎯
# Good luck, and remember to test each part of your code to ensure it works correctly!
