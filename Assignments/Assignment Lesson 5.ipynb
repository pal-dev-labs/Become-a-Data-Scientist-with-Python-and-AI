# %% [markdown]
# # PHYTON FOR ECONOMIC APPLICATION - ASSIGNMENT LESSON 5
# # Conditional Statements and Loops
#
# ## INSTRUCTIONS
# - Try to write the code by yourself based on basic instructions provided in the notebook Lesson 5.
# - Run the cell and, in case, try to fix the error comparing with code in notebooks. This phase is IMPORTANT to fix in memory commands and syntax
# - If you still have problems, go to ChatGPT and write "create a python code that perform ..exercise..instructions". Cut and paste the code in a new notebook cell
# - Customize the code if necessary and run it.
# - IMPORTANT: go through each single instructions of the new code and try to execute mentally the code in order to understand the flow of the program and the meaning of the commands. There are 2 goals here. First: fix commands meaning and syntax. Second: understand solution strategy
# - COMPARE the new code with previous code in order to understand the errors you made
#
# You can also go to stackoverflow to ask question about python code.
#
# ## Exercise 1: Even or Odd Energy
# Write a program that asks the user to input a kinetic energy value (KE). If KE is even, print `"The energy is even"`, otherwise, print `"The energy is odd"`.
#
# ## Exercise 2: Free Fall Time Classification
# Ask the user to input a free-fall time `t` (in seconds). Classify it into:
# - `"Short fall"` if `t < 2` seconds,
# - `"Moderate fall"` if `2 ≤ t ≤ 5` seconds,
# - `"Long fall"` if `t > 5` seconds.
#
# ## Exercise 3: Motion Equation Solver
# Ask the user for initial velocity `v0`, acceleration `a`, and time `t`. Compute the velocity using `v = v0 + at`. If `v > 50 m/s`, print `"High speed!"`, otherwise `"Safe speed"`.
#
# ## Exercise 4: Temperature State of Water
# Ask the user for a temperature in Celsius and classify the state of water:
# - `"Solid"` if `T < 0°C`,
# - `"Liquid"` if `0°C ≤ T < 100°C`,
# - `"Gas"` if `T ≥ 100°C`.
#
# ## Exercise 5: Prime Number Checker
# Ask the user for a number and check if it's prime using a `for` loop.
#
# ## Exercise 6: Sum of Forces in Equilibrium
# Ask for three force magnitudes acting on a point in different directions. Use a `for` loop to sum them. If the sum is zero, print `"The system is in equilibrium"`, otherwise `"The system is not in equilibrium"`.
#
# ## Exercise 7: Quadratic Equation Solver
# Ask the user for coefficients `a`, `b`, and `c` of a quadratic equation. Calculate the discriminant and:
# - If `Δ < 0`, print `"No real solutions"`,
# - If `Δ = 0`, print `"One real solution"`,
# - If `Δ > 0`, print `"Two real solutions"`.
#
# ## Exercise 8: Newton's Law of Cooling
# Simulate Newton’s law of cooling: `T_new = T_old - k * (T_old - T_env)`, iterating for `n` steps using a `for` loop.
#
# ## Exercise 8-b: Pendulum Period Calculation
# Compute the period `T` of a simple pendulum using `T = 2π√(L/g)`. Allow the user to input `L` (length) and iterate over multiple values.

# %% [markdown]
# ## Exercise 9: Gravitational Force Between Multiple Objects
# Create a dictionary where the keys are planet names and the values are their masses (in kg). Ask the user to input two planet names and the distance between them (in meters). Use Newton’s law of universal gravitation:
#
# $
# F = G \frac{m_1 m_2}{r^2}
# $
#
# where $ G = 6.674 \times 10^{-11} $. Compute and display the gravitational force.
#
# ## Exercise 10: Sorting Objects by Density
# Create a list of dictionaries where each dictionary contains an object's `"name"`, `"mass"` (kg), and `"volume"` (m³). Compute their densities using `density = mass / volume` and sort the objects by density in descending order.
#
# ## Exercise 11: Temperature Conversion Table
# Create a list of temperatures in Celsius. Use a `for` loop to convert each value to Fahrenheit using:
#
# $
# F = \frac{9}{5}C + 32
# $
#
# Store the results in a dictionary where the keys are Celsius values and the values are Fahrenheit equivalents.
#
# ## Exercise 12: Identifying Elements by Atomic Number
# Create a dictionary where keys are atomic numbers (1-10) and values are element names (e.g., `{1: "Hydrogen", 2: "Helium"}`). Ask the user for an atomic number and display the corresponding element.
#
# ## Exercise 13: Projectile Motion with List Storage
# Simulate a projectile launched at an initial velocity $ v_0 $ and angle $ \theta $. Compute the horizontal displacement $ x $ at time intervals using:
#
# $
# x = v_0 \cos(\theta) t
# $
#
# Store each value of $ x $ in a list and print the result after `n` iterations.
#
# ## Exercise 14: Fibonacci Sequence for Approximating the Golden Ratio
# Generate the first `n` Fibonacci numbers using a `for` loop. Store them in a list and compute the ratio of consecutive terms $ F_n / F_{n-1} $ to approximate the golden ratio.
#
# ## Exercise 15: Resistance in Parallel Circuits
# Given a list of resistances in a circuit, compute the total resistance using:
#
# $
# \frac{1}{R_{total}} = \sum \frac{1}{R_i}
# $
#
# where each \( R_i \) is a resistance from the list.
#
# ## Exercise 16: Classifying Star Temperatures
# Create a dictionary where the keys are spectral classes (`"O"`, `"B"`, `"A"`, `"F"`, `"G"`, `"K"`, `"M"`) and values are typical temperature ranges. Ask the user to enter a temperature and classify the star.
#
# ## Exercise 17: Finding Maximum Kinetic Energy in a Dataset
# Given a list of objects where each has `"mass"` (kg) and `"velocity"` (m/s), compute kinetic energy for each:
#
# $
# KE = \frac{1}{2} m v^2
# $
#
# Store the values in a dictionary and find the object with the highest KE.
#
# ## Exercise 18: Simulating Decay of a Radioactive Sample
# Given an initial quantity `Q0` and a half-life `T_half`, simulate the decay over `n` time intervals using:
#
# $
# Q_t = Q_0 \times \left(\frac{1}{2}\right)^{t/T_{\text{half}}}
# $
#
# Store the values in a list and display them.
